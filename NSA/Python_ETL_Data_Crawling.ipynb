# %% [markdown]
# # Python ETL Data Crawling

# %% [markdown]
# ## 使用requests.get

# %%
import requests
res = requests.get('http://127.0.0.1:8000/')
#print res.text
#print res.status_code 
print res.headers['content-type']
# Out:
# text/html; charset=utf-8

# %% [markdown]
# ## 將網頁讀進BeautifulSoup 中

# %%
from bs4 import BeautifulSoup 
html_sample = ' \
<html> \
 <body> \
 <h1 id="title">Hello World</h1> \
 <a href="#" class="link">This is link1</a> \
 <a href="# link2" class="link">This is link2</a> \
 </body> \
 </html>'

soup = BeautifulSoup(html_sample)
print soup.text
# Out:
#  Hello World This is link1 This is link2

# %% [markdown]
# ## 使用Find 找出(第一個)含有a tag 的元素

# %%
soup = BeautifulSoup(html_sample) 
alink = soup.find('a') 
print alink.text
# Out:
# This is link1

# %% [markdown]
# ## 找出所有含a tag 的HTML 元素

# %%
for alink in soup.findAll('a'): 
    print alink.contents
# Out:
# [u'This is link1']
# [u'This is link2']

# %% [markdown]
# ## 使用Find 找出所有id為title的元素

# %%
alink = soup.find('h1', {'id':'title'}) 
print alink
# Out:
# <h1 id="title">Hello World</h1>

# %% [markdown]
# ## 取得含有特定class的元素

# %%
soup = BeautifulSoup(html_sample) 
for link in soup.findAll('a', {'class': 'link'}): 
    print link
# Out:
# <a class="link" href="#">This is link1</a>
# <a class="link" href="# link2">This is link2</a>

# %% [markdown]
# ## 取得所有a tag 內的連結

# %%
alinks = soup.findAll('a', {'href': True}) 
for link in alinks: 
    print link['href']
    
    
a = soup.select("a")
a
# Out:
# #
# # link2
# [<a class="link" href="#">This is link1</a>,
#  <a class="link" href="# link2">This is link2</a>]

# %% [markdown]
# ## 設定POST 的Form Data

# %%
# -*- coding: utf-8 -*- 
import requests

payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }

# %% [markdown]
# ## 送出Post 取得資料

# %%
user_post = requests.post("http://127.0.0.1:8000/query", data=payload) 
response_text = user_post.text.encode('utf8') 
#print response_text

# %% [markdown]
# ## 取得資料筆數

# %%
from bs4 import BeautifulSoup

user_post = requests.post("http://127.0.0.1:8000/query", data=payload) 
response_text = user_post.text.encode('utf8') 
soup = BeautifulSoup(response_text) 
rec_number_element = soup.select('.T11b')[0]
rec_number = int(rec_number_element.text) 
print rec_number
# Out:
# 265

# %% [markdown]
# ## 將資料筆數轉換成頁數

# %%
from math import ceil 
page_number = int(ceil(float(rec_number) / 100)) 
print page_number
# Out:
# 3

# %% [markdown]
# ## 字串格式化 - 使用format

# %%
page_format = "http://127.0.0.1:8000/pageIndex={0}" 
for page in range(1, page_number + 1): 
    print page_format.format(page)
# Out:
# http://127.0.0.1:8000/pageIndex=1
# http://127.0.0.1:8000/pageIndex=2
# http://127.0.0.1:8000/pageIndex=3

# %% [markdown]
# ## 使用%

# %%
page_format = "http://127.0.0.1:8000/pageIndex=%d" 
for page in range(1, page_number + 1): 
    print page_format%(page)
# Out:
# http://127.0.0.1:8000/pageIndex=1
# http://127.0.0.1:8000/pageIndex=2
# http://127.0.0.1:8000/pageIndex=3

# %% [markdown]
# ## 取得每頁標案清單的內容

# %%
page_format = "http://127.0.0.1:8000/pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = requests.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8')
    #print bid_response

# %% [markdown]
# ## 先拿一頁做試驗

# %%
page_format = "http://127.0.0.1:8000/pageIndex=%d" 
page = 1 
bid_list = requests.get(page_format%(page)) 
bid_response = bid_list.text.encode('utf8') 
bid_soup = BeautifulSoup(bid_response) 
#print bid_response
bid_table = bid_soup.select('#print_area')[0]
#print bid_table

# %% [markdown]
# ## 去掉標頭

# %%
bid_rows = bid_table.select('tr')[1:] 
#print bid_rows

# %% [markdown]
# ## 去掉標頭跟頁次

# %%
bid_rows = bid_table.select('tr')[1:-1] 
#print bid_rows

# %% [markdown]
# ## 索引範例

# %%
ary = [1,2,3,4,5,6] 
print ary[1:-1] 
#[2,3,4,5]
# Out:
# [2, 3, 4, 5]

# %% [markdown]
# ## 抓出每一列所有的連結

# %%
bid_rows = bid_table.select('tr')[1:-1] 
for bid_row in bid_rows: 

    links = [tag['href']for tag in bid_row.select('a')] 

    #print links

# %% [markdown]
# ## 用[0]取第一個連結

# %%
for bid_row in bid_rows: 

    links = [tag['href'] 
      for tag in bid_row.select('a')][0]
 
    #print links

# %% [markdown]
# ## 取得實際連結

# %%
for bid_row in bid_rows: 
    link = [tag['href'] for tag in bid_row.select('a')][0] 
    link_href = "http://127.0.0.1:8000/" + link 
    #print link_href

# %% [markdown]
# ## 使用urljoin

# %%
import urlparse
for bid_row in bid_rows: 
    link = [tag['href'] for tag in bid_row.select('a')][0] 
    link_href = urlparse.urljoin("http://127.0.0.1:8000/query", link)
    #print link_href

# %% [markdown]
# ## 複習一下如何使用Python做檔案寫入

# %%
f = open("test.txt", 'w') 
f.write("Hello World\n") 
f.close()

# %% [markdown]
# ## 將每頁標案清單的連結存入檔案

# %%
bid_file = open("bid_list.txt", 'w') 
page_format = "http://127.0.0.1:8000/pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = requests.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8') 
    bid_soup = BeautifulSoup(bid_response) 
    bid_table = bid_soup.select("#print_area") [0]
    bid_rows = bid_table.select('tr')[1:-1] 
    for bid_row in bid_rows:         
        link = [tag['href'] for tag in bid_row.select('a')][0] 
        link_href = urlparse.urljoin("http://127.0.0.1:8000/query", link) 
        bid_file.write(link_href + "\n") 
bid_file.close()

# %% [markdown]
# ## 0. 引入該用的package

# %%
import requests
import urlparse 
from bs4 import BeautifulSoup 
from math import ceil

# %% [markdown]
# ## 1. 設定查詢條件

# %%
payload = { 'method':'search', 'searchMethod':'true', 'searchTarget':'ATM',
 'orgName':'', 'orgId':'', 'hid_1':'1',
 'tenderName':'', 'tenderId':'', 'tenderStatus':'4,5,21,29',
 'tenderWay':'', 'awardAnnounceStartDate':'103/04/29',
 'awardAnnounceEndDate':'103/04/29', 'radProctrgCate':'3', 
 'proctrgCate':'3', 'tenderRange':'', 'minBudget':'',
 'maxBudget':'', 'item':'','hid_2':'1',
 'gottenVendorName':'', 'gottenVendorId':'', 'hid_3':'1',
 'submitVendorName':'', 'submitVendorId':'', 'location':'',
 'priorityCate':'', 'isReConstruct':'', 'btnQuery':'查詢' }

user_post = requests.post("http://web.pcc.gov.tw/tps/pss/tender.do?searchMode=common&searchType=advance", data=payload) 
response_text = user_post.text.encode('utf8')

# %% [markdown]
# ## 2. 計算抓取頁數

# %%
soup = BeautifulSoup(response_text) 
rec_number_element = soup.select(".T11b" )[0] 
rec_number = int(rec_number_element.text)
page_number = int(ceil(float(rec_number) / 100))

# %% [markdown]
# ## 3. 依每頁抓取所有標案連結 &
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 4. 存入每頁標案連結

# %%
bid_file = open("bid_list.txt", 'w') 
page_format = "http://127.0.0.1:8000/pageIndex=%d" 
for page in range(1, page_number + 1): 
    bid_list = rs.get(page_format%(page)) 
    bid_response = bid_list.text.encode('utf8') 
    bid_soup = BeautifulSoup(bid_response)
    bid_table = bid_soup.select("#print_area")[0] 
    bid_rows = bid_table.select('tr')[1:-1] 
    for bid_row in bid_rows: 
        link = [tag['href'] for tag in bid_row.select('a')][0] 
        link_href = urlparse.urljoin("http://127.0.0.1:8000/query", link)
        bid_file.write(link_href + "\n") 
bid_file.close()

# %% [markdown]
# ## 計算總共存了多少個連結

# %%
line_num = 0 
f = open("bid_list.txt", "r") 
for line in f.readlines(): 
    line_num = line_num + 1 
print line_num 
f.close()
# Out:
# 265

# %% [markdown]
# ## 判斷抓下來的資料筆數
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 是否與網頁上呈現的相同

# %%
soup = BeautifulSoup(response_text) 
rec_number_element = soup.select(".T11b" )[0] 
rec_number = int(rec_number_element.text)

line_num = 0 
f = open("bid_list.txt", "r") 
for line in f.readlines(): 
    line_num = line_num + 1 
print line_num 
f.close() 

#使用if 判斷
if rec_number == line_num: 
    print "record number on web page is equal to number of lines in file"
# Out:
# 265
# record number on web page is equal to number of lines in file

# %% [markdown]
# ## 使用requests.get 抓取標案細節

# %%
request_get = requests.get("http://127.0.0.1:8000/pkAtmMain=51239291&tenderCaseNo=0607L1030328") 
response = request_get.text.encode('utf8') 
#print response

# %% [markdown]
# ## 取得id為printArea 的區塊

# %%
request_get = requests.get("http://127.0.0.1:8000/pkAtmMain=51239291&tenderCaseNo=0607L1030328")
response = request_get.text.encode('utf8') 
soup = BeautifulSoup(response)
printarea = soup.select('#printArea') [0]
#print printarea

# %% [markdown]
# ## 將標案資料寫進檔案中

# %%
bid_detail = open("bid_detail.txt", 'w') 
request_get = requests.get("http://127.0.0.1:8000/pkAtmMain=51239291&tenderCaseNo=0607L1030328")
response = request_get.text.encode('utf8') 
soup = BeautifulSoup(response)
printarea = soup.select('#printArea') [0]
bid_detail.write(printarea) 
bid_detail.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-74631c502fb8> in <module>()
#       4 soup = BeautifulSoup(response)
#       5 printarea = soup.select('#printArea') [0]
# ----> 6 bid_detail.write(printarea)
#       7 bid_detail.close()
#
# TypeError: expected a character buffer object

# %% [markdown]
# ## 使用prettify 將soup 抓到的tag
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 轉換成str

# %%
bid_detail = open("bid_detail.txt", 'w') 
request_get = requests.get("http://127.0.0.1:8000/pkAtmMain=51239291&tenderCaseNo=0607L1030328")
response = request_get.text.encode('utf8') 
soup = BeautifulSoup(response)
printarea = soup.select('#printArea') [0] 
bid_detail.write(printarea.prettify("utf-8")) 
bid_detail.close()

# %% [markdown]
# ## 怎麼找出案號是否會重複?

# %%
case_dic = {} 
f = open("bid_list.txt", "r") 
for line in f.readlines(): 
    rec = line.strip() 
    caseno = rec.split('tenderCaseNo=')[1] 
    if caseno not in case_dic: 
        case_dic[caseno] = 1 
    else: 
        print caseno 
f.close()
# Out:
# 1030401
# 10302
# 10302
# 103003
# 1030415

# %% [markdown]
# ## 如何從url 取得這兩個值?

# %%
link = "http://127.0.0.1:8000/pkAtmMain=51239291&tenderCaseNo=0607L1030328"

# %% [markdown]
# ## 使用split

# %%
rear_substring = link.split("pkAtmMain=")[1] 
param = rear_substring.split("&tenderCaseNo=") 
pkAtmMain= param[0] 
caseno= param[1] 
print pkAtmMain,caseno
# Out:
# 51239291 0607L1030328

# %% [markdown]
# ## re.match 範例

# %%
import re 
m = re.match(r"(?P<FirstName>\w+) (?P<LastName>\w+)", "David Chiu") 
print m.group("FirstName"), m.group("LastName")
# Out:
# David Chiu

# %% [markdown]
# ## 使用re.match

# %%
import re 
link = "http://127.0.0.1:8000/pkAtmMain=51239291&tenderCaseNo=0607L1030328" 
m = re.match(r"([^ ]+)pkAtmMain=(?P<pkAtmMain>.+)&tenderCaseNo=(?P<tenderCaseNo>.+)", link) 
print m.group('pkAtmMain'), m.group('tenderCaseNo')
# Out:
# 51239291 0607L1030328

# %% [markdown]
# ## 讀取bid_list.txt
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 依序抓出標案內容

# %%
from bs4 import BeautifulSoup 
import re, grequests, time 
import os
if not os.path.exists('gov'):
    os.mkdir('gov')
    
url_ary = []

bid_list = open('bid_list.txt', 'r') 

for line in bid_list.readlines(): 
    pagelink = line.strip() 
    url_ary.append(pagelink)
    m = re.match(r"([^ ]+)pkAtmMain=(?P<pkAtmMain>.+)&tenderCaseNo=(?P<tenderCaseNo>.+)", pagelink) 
    filename = "%s_%s"%(m.group('pkAtmMain'), m.group('tenderCaseNo')) 
    request_get = requests.get(pagelink) 
    response = request_get.text.encode('utf8') 
    soup = BeautifulSoup(response)
    printarea = soup.select('#printArea')[0]
    bid_detail = open("gov/%s.txt"%(filename), 'w') 
    bid_detail.write(printarea.prettify("utf-8")) 
    bid_detail.close() 
    #print filename
    #time.sleep(0.2)
bid_list.close()

# %% [markdown]
# ## 抓取標案細節完成版

# %%
from bs4 import BeautifulSoup 
import re, grequests, time 
import os
if not os.path.exists('gov'):
    os.mkdir('gov')
    
url_ary = []

bid_list = open('bid_list.txt', 'r') 

for line in bid_list.readlines(): 
    pagelink = line.strip() 
    url_ary.append(pagelink)
    m = re.match(r"([^ ]+)pkAtmMain=(?P<pkAtmMain>.+)&tenderCaseNo=(?P<tenderCaseNo>.+)", pagelink) 
    filename = "%s_%s"%(m.group('pkAtmMain'), m.group('tenderCaseNo')) 
    request_get = requests.get(pagelink) 
    response = request_get.text.encode('utf8') 
    soup = BeautifulSoup(response)
    printarea = soup.select('#printArea')[0]
    bid_detail = open("gov/%s.txt"%(filename), 'w') 
    bid_detail.write(printarea.prettify("utf-8")) 
    bid_detail.close() 
    print filename
    time.sleep(0.2)
bid_list.close()
